# %% [markdown]
# # 张量的索引操作
# -

# %%
import torch

# %%
tensor1 = torch.randint(1, 10, (3,5,4))
print("tensor1:", tensor1)
# Out:
# tensor1: tensor([[[1, 3, 8, 7],
#          [8, 9, 4, 4],
#          [7, 6, 3, 4],
#          [3, 4, 7, 3],
#          [2, 3, 7, 8]],
#
#         [[9, 7, 2, 4],
#          [7, 7, 9, 1],
#          [1, 5, 1, 7],
#          [9, 4, 2, 7],
#          [8, 4, 4, 8]],
#
#         [[4, 7, 4, 1],
#          [1, 5, 2, 6],
#          [8, 4, 3, 8],
#          [3, 8, 9, 9],
#          [3, 6, 6, 5]]])

# %%
# 简单索引操作
